# %%
pip install requests
pip install pandas
pip install tqdm
pip install bs4
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Using legacy 'setup.py install' for bs4, since package 'wheel' is not installed.
# Installing collected packages: soupsieve, beautifulsoup4, bs4
#     Running setup.py install for bs4: started
#     Running setup.py install for bs4: finished with status 'done'
# Successfully installed beautifulsoup4-4.12.2 bs4-0.0.1 soupsieve-2.5
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.1; however, version 23.2.1 is available.
# You should consider upgrading via the 'c:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import requests
import random
import pandas as pd 
from tqdm import tqdm
from bs4  import BeautifulSoup
from cred_here_Template import YOUR_API_KEY
import json 
from tqdm import tqdm
import time

import ast

# %%
YOUR_API_KEY = YOUR_API_KEY

# %%
df = pd.read_csv('precios_de_combustibles_gt.csv')

# %%
df.head(2)
# Out:
#    Periodo  Mes  Codigo_departamento Departamento  Codigo_municipio  \
# 0     2023   12                    1    GUATEMALA              1010
# 1     2023   12                    1    GUATEMALA              1010
#
#    Municipio                      Nombre_comercial Bandera  \
# 0  GUATEMALA       ESTACION DE SERVICIO AEROPUERTO  TEXACO
# 1  GUATEMALA  ESTACION DE SERVICIO ALAMEDA PALMIRA   SHELL
#
#                           Direccion Producto  Precio Estado
# 0  1 AVENIDA 1-10 ZONA 10 GUATEMALA   DIESEL   35.15      A
# 1   1 AVENIDA 1-10 ZONA 7 GUATEMALA   DIESEL   35.15      A

# %% [markdown]
# <h1><center>Geocoding Api's</center></h1>
#
# ## Google API
#
# * [**Google_Free_Tier**](https://cloud.google.com/free/?utm_source=google&utm_medium=cpc&utm_campaign=latam-LATAM-all-es-dr-AKWS-all-all-trial-p-dr-1011454-LUAC0013610&utm_content=text-ad-none-any-DEV_c-CRE_540885993580-ADGP_Hybrid%20%7C%20BKWS%20-%20PHR%20%7C%20Txt%20~%20Management-Tools_Console-KWID_43700065922071537-kwd-651816590614&utm_term=KW_google%20console-ST_Google%20Console&gclid=Cj0KCQjwnbmaBhD-ARIsAGTPcfWVMlJlTFywFNaAo8P-MNL4_gM6L7yucqAQ37xg1AIEHzpAzF_kkAoaAsszEALw_wcB&gclsrc=aw.ds)
# * [**Google_Api_Pricing**](https://mapsplatform.google.com/pricing/)
#
# ## HERE Platform
#
# * [**Here_Register**](https://platform.here.com/sign-up?step=verify-identity&aid=www.here.com-start-building)
# * [**Here_Princing**](https://www.here.com/pricing)
# * [**Geocoding_Documentation**](https://developer.here.com/documentation/geocoding-search-api/dev_guide/topics/endpoint-geocode-brief.html)

# %% [markdown]
# # Clean Data

# %%
df[df['Periodo']==2023]['Mes'].max()
# Out:
# 12

# %%
df2 =  df[(df['Periodo']==2023)]

# %%
df2['Municipio'].value_counts().head(10)
# Out:
# Municipio
# GUATEMALA    2760
# Name: count, dtype: int64

# %%
df3 = df2

# %%
df3.head(2)
# Out:
#    Periodo  Mes  Codigo_departamento Departamento  Codigo_municipio  \
# 0     2023   12                    1    GUATEMALA              1010
# 1     2023   12                    1    GUATEMALA              1010
#
#    Municipio                      Nombre_comercial Bandera  \
# 0  GUATEMALA       ESTACION DE SERVICIO AEROPUERTO  TEXACO
# 1  GUATEMALA  ESTACION DE SERVICIO ALAMEDA PALMIRA   SHELL
#
#                           Direccion Producto  Precio Estado
# 0  1 AVENIDA 1-10 ZONA 10 GUATEMALA   DIESEL   35.15      A
# 1   1 AVENIDA 1-10 ZONA 7 GUATEMALA   DIESEL   35.15      A

# %%
df3['Municipio'].unique()
# Out:
# array(['GUATEMALA'], dtype=object)

# %%
df3['Full_Address'] = df3.apply(lambda x : x['Direccion'] + ', GUATEMALA' , axis = 1)

# %%
df3['Full_Address'].nunique()
# Out:
# 867

# %%
df3['Full_Address'][0]
# Out:
# '1 AVENIDA 1-10 ZONA 10 GUATEMALA, GUATEMALA'

# %%
df3
# Out:
#       Periodo  Mes  Codigo_departamento Departamento  Codigo_municipio  \
# 0        2023   12                    1    GUATEMALA              1010
# 1        2023   12                    1    GUATEMALA              1010
# 2        2023   12                    1    GUATEMALA              1010
# 3        2023   12                    1    GUATEMALA              1010
# 4        2023   12                    1    GUATEMALA              1010
# ...       ...  ...                  ...          ...               ...
# 2755     2023   12                    1    GUATEMALA              1010
# 2756     2023   12                    1    GUATEMALA              1010
# 2757     2023   12                    1    GUATEMALA              1010
# 2758     2023   12                    1    GUATEMALA              1010
# 2759     2023   12                    1    GUATEMALA              1010
#
#       Municipio                        Nombre_comercial     Bandera  \
# 0     GUATEMALA         ESTACION DE SERVICIO AEROPUERTO      TEXACO
# 1     GUATEMALA    ESTACION DE SERVICIO ALAMEDA PALMIRA       SHELL
# 2     GUATEMALA    ESTACION DE SERVICIO ALCARAVAN YOPAL       SHELL
# 3     GUATEMALA  ESTACION DE SERVICIO ALTO DE GUALANDAY         UNO
# 4     GUATEMALA     ESTACION DE SERVICIO AMERICAS PASTO       SHELL
# ...         ...                                     ...         ...
# 2755  GUATEMALA                SERVICENTRO PANAMERICANA         UNO
# 2756  GUATEMALA                       SERVICENTRO PASTO  DON ARTURO
# 2757  GUATEMALA          SERVICENTRO PLAZA BOLVAR S.A.S  DON ARTURO
# 2758  GUATEMALA         SERVICENTRO PLAZA BOLIVAR S.A.S         UNO
# 2759  GUATEMALA          SERVICENTRO PRIMAX EL PORVENIR      TEXACO
#
#                              Direccion Producto  Precio Estado  \
# 0     1 AVENIDA 1-10 ZONA 10 GUATEMALA   DIESEL   35.15      A
# 1      1 AVENIDA 1-10 ZONA 7 GUATEMALA   DIESEL   35.15      A
# 2      1 AVENIDA 1-10 ZONA 9 GUATEMALA   DIESEL   37.50      A
# 3     1 AVENIDA 1-11 ZONA 16 GUATEMALA   DIESEL   33.90      A
# 4     1 AVENIDA 1-11 ZONA 19 GUATEMALA   DIESEL   36.50      A
# ...                                ...      ...     ...    ...
# 2755  9 AVENIDA 4-21 ZONA 14 GUATEMALA    SUPER   35.15      A
# 2756  9 AVENIDA 4-21 ZONA 19 GUATEMALA    SUPER   33.14      A
# 2757   9 AVENIDA 4-21 ZONA 7 GUATEMALA    SUPER   36.75      A
# 2758   9 AVENIDA 4-9 ZONA 12 GUATEMALA    SUPER   35.17      A
# 2759    9 AVENIDA 4-9 ZONA 8 GUATEMALA    SUPER   36.14      A
#
#                                      Full_Address
# 0     1 AVENIDA 1-10 ZONA 10 GUATEMALA, GUATEMALA
# 1      1 AVENIDA 1-10 ZONA 7 GUATEMALA, GUATEMALA
# 2      1 AVENIDA 1-10 ZONA 9 GUATEMALA, GUATEMALA
# 3     1 AVENIDA 1-11 ZONA 16 GUATEMALA, GUATEMALA
# 4     1 AVENIDA 1-11 ZONA 19 GUATEMALA, GUATEMALA
# ...                                           ...
# 2755  9 AVENIDA 4-21 ZONA 14 GUATEMALA, GUATEMALA
# 2756  9 AVENIDA 4-21 ZONA 19 GUATEMALA, GUATEMALA
# 2757   9 AVENIDA 4-21 ZONA 7 GUATEMALA, GUATEMALA
# 2758   9 AVENIDA 4-9 ZONA 12 GUATEMALA, GUATEMALA
# 2759    9 AVENIDA 4-9 ZONA 8 GUATEMALA, GUATEMALA
#
# [2760 rows x 13 columns]

# %%
estaciones =  df3[['Nombre_comercial','Direccion','Full_Address']].drop_duplicates(subset = 'Nombre_comercial')
# estaciones.reset_index(inplace = True)
# estaciones.drop(columns = 'index',inplace = True)

# %%
estaciones
# Out:
#                            Nombre_comercial                         Direccion  \
# 0           ESTACION DE SERVICIO AEROPUERTO  1 AVENIDA 1-10 ZONA 10 GUATEMALA
# 1      ESTACION DE SERVICIO ALAMEDA PALMIRA   1 AVENIDA 1-10 ZONA 7 GUATEMALA
# 2      ESTACION DE SERVICIO ALCARAVAN YOPAL   1 AVENIDA 1-10 ZONA 9 GUATEMALA
# 3    ESTACION DE SERVICIO ALTO DE GUALANDAY  1 AVENIDA 1-11 ZONA 16 GUATEMALA
# 4       ESTACION DE SERVICIO AMERICAS PASTO  1 AVENIDA 1-11 ZONA 19 GUATEMALA
# ..                                      ...                               ...
# 915                SERVICENTRO PANAMERICANA  9 AVENIDA 4-21 ZONA 14 GUATEMALA
# 916                       SERVICENTRO PASTO  9 AVENIDA 4-21 ZONA 19 GUATEMALA
# 917          SERVICENTRO PLAZA BOLVAR S.A.S   9 AVENIDA 4-21 ZONA 7 GUATEMALA
# 918         SERVICENTRO PLAZA BOLIVAR S.A.S   9 AVENIDA 4-9 ZONA 12 GUATEMALA
# 919          SERVICENTRO PRIMAX EL PORVENIR    9 AVENIDA 4-9 ZONA 8 GUATEMALA
#
#                                     Full_Address
# 0    1 AVENIDA 1-10 ZONA 10 GUATEMALA, GUATEMALA
# 1     1 AVENIDA 1-10 ZONA 7 GUATEMALA, GUATEMALA
# 2     1 AVENIDA 1-10 ZONA 9 GUATEMALA, GUATEMALA
# 3    1 AVENIDA 1-11 ZONA 16 GUATEMALA, GUATEMALA
# 4    1 AVENIDA 1-11 ZONA 19 GUATEMALA, GUATEMALA
# ..                                           ...
# 915  9 AVENIDA 4-21 ZONA 14 GUATEMALA, GUATEMALA
# 916  9 AVENIDA 4-21 ZONA 19 GUATEMALA, GUATEMALA
# 917   9 AVENIDA 4-21 ZONA 7 GUATEMALA, GUATEMALA
# 918   9 AVENIDA 4-9 ZONA 12 GUATEMALA, GUATEMALA
# 919    9 AVENIDA 4-9 ZONA 8 GUATEMALA, GUATEMALA
#
# [907 rows x 3 columns]

# %%
address = estaciones['Full_Address'][0]
url = f'https://geocode.search.hereapi.com/v1/geocode?q={address}&apiKey={YOUR_API_KEY}'
response = requests.get(url).json()

# %%
response
# Out:
# {'items': [{'title': 'Avenida 1 1-10, 01062 Fraijanes, Guatemala',
#    'id': 'here:af:streetsection:9THCnZ.IauLJOqOLZQLPzC:EAIaBDEtMTAoOw',
#    'resultType': 'houseNumber',
#    'houseNumberType': 'interpolated',
#    'address': {'label': 'Avenida 1 1-10, 01062 Fraijanes, Guatemala',
#     'countryCode': 'GTM',
#     'countryName': 'Guatemala',
#     'county': 'Guatemala',
#     'city': 'Fraijanes',
#     'district': 'Zona 1',
#     'street': 'Avenida 1',
#     'postalCode': '01062',
#     'houseNumber': '1-10'},
#    'position': {'lat': 14.46466, 'lng': -90.44077},
#    'access': [{'lat': 14.46461, 'lng': -90.4409}],
#    'mapView': {'west': -90.4417,
#     'south': 14.46376,
#     'east': -90.43984,
#     'north': 14.46556},
#    'houseNumberFallback': True,
#    'scoring': {'queryScore': 0.91,
#     'fieldScore': {'country': 1.0,
#      'county': 1.0,
#      'district': 0.95,
#      'streets': [1.0],
#      'houseNumber': 0.4}}},
#   {'title': 'Avenida 1 1-10, 04006 Tecpán Guatemala, Guatemala',
#    'id': 'here:af:streetsection:GPJ4dPgLYzuOSjYld3GouB:EAIaBDEtMTAoOw',
#    'resultType': 'houseNumber',
#    'houseNumberType': 'interpolated',
#    'address': {'label': 'Avenida 1 1-10, 04006 Tecpán Guatemala, Guatemala',
#     'countryCode': 'GTM',
#     'countryName': 'Guatemala',
#     'county': 'Chimaltenango',
#     'city': 'Tecpán Guatemala',
#     'district': 'Zona 1',
#     'street': 'Avenida 1',
#     'postalCode': '04006',
#     'houseNumber': '1-10'},
#    'position': {'lat': 14.761, 'lng': -90.99161},
#    'access': [{'lat': 14.76092, 'lng': -90.99172}],
#    'mapView': {'west': -90.99254,
#     'south': 14.7601,
#     'east': -90.99068,
#     'north': 14.7619},
#    'houseNumberFallback': True,
#    'scoring': {'queryScore': 0.84,
#     'fieldScore': {'country': 1.0,
#      'city': 0.43,
#      'district': 0.95,
#      'streets': [1.0],
#      'houseNumber': 0.4}}},
#   {'title': '1 Avenida a 1-10, 04006 Tecpán Guatemala, Guatemala',
#    'id': 'here:af:streetsection:k2.tWftrfgIzE2244ZdeOA:EAIaBDEtMTA',
#    'resultType': 'houseNumber',
#    'houseNumberType': 'interpolated',
#    'address': {'label': '1 Avenida a 1-10, 04006 Tecpán Guatemala, Guatemala',
#     'countryCode': 'GTM',
#     'countryName': 'Guatemala',
#     'county': 'Chimaltenango',
#     'city': 'Tecpán Guatemala',
#     'district': 'Zona 1',
#     'street': '1 Avenida a',
#     'postalCode': '04006',
#     'houseNumber': '1-10'},
#    'position': {'lat': 14.76125, 'lng': -90.9913},
#    'access': [{'lat': 14.76116, 'lng': -90.9914}],
#    'mapView': {'west': -90.99223,
#     'south': 14.76035,
#     'east': -90.99037,
#     'north': 14.76215},
#    'scoring': {'queryScore': 0.9,
#     'fieldScore': {'country': 1.0,
#      'city': 0.43,
#      'district': 0.95,
#      'streets': [0.89],
#      'houseNumber': 1.0}}},
#   {'title': 'Avenida 1 1-10, 01062 Fraijanes, Guatemala',
#    'id': 'here:af:streetsection:LAIFQADSEMB6E1PxZqfK5A:EAIaBDEtMTAoOw',
#    'resultType': 'houseNumber',
#    'houseNumberType': 'interpolated',
#    'address': {'label': 'Avenida 1 1-10, 01062 Fraijanes, Guatemala',
#     'countryCode': 'GTM',
#     'countryName': 'Guatemala',
#     'county': 'Guatemala',
#     'city': 'Fraijanes',
#     'district': 'Zona 4',
#     'street': 'Avenida 1',
#     'postalCode': '01062',
#     'houseNumber': '1-10'},
#    'position': {'lat': 14.46665, 'lng': -90.44467},
#    'access': [{'lat': 14.46669, 'lng': -90.4448}],
#    'mapView': {'west': -90.4456,
#     'south': 14.46575,
#     'east': -90.44374,
#     'north': 14.46755},
#    'houseNumberFallback': True,
#    'scoring': {'queryScore': 0.85,
#     'fieldScore': {'country': 1.0,
#      'county': 1.0,
#      'district': 0.55,
#      'streets': [1.0],
#      'houseNumber': 0.4}}}]}

# %%
def Get_Coords(address,YOUR_API_KEY):
    
    url = f'https://geocode.search.hereapi.com/v1/geocode?q={address}&apiKey={YOUR_API_KEY}'
    
    try : 
        response = requests.get(url).json()
        CleanAddress = response['items'][0]['title'].upper()
        LAT = response['items'][0]['position']['lat']
        LNG = response['items'][0]['position']['lng']
        
        results = [CleanAddress,LAT,LNG]
        
    except :
        results = ['Not Found','NA','NA']
        
    return results

# %%
Get_Coords(address,YOUR_API_KEY)
# Out:
# ['AVENIDA 1 1-10, 01062 FRAIJANES, GUATEMALA', 14.46466, -90.44077]

# %% [markdown]
# # Extracción de coordenadas

# %%
coordenadas = []
tiempo = [1,2,2.5]

for i in tqdm(range(len(estaciones['Full_Address'])),colour = 'green'):
    
    try :
        R = Get_Coords(estaciones['Full_Address'][i],YOUR_API_KEY)
        geo_source = R[1],R[2]
        coordenadas.append(geo_source)
        
    except :
        coordenadas.append('Error')
        
    time.sleep(random.choices(tiempo)[0])

# %%
estaciones['Coords'] = coordenadas

# %%
estaciones['Coords'].value_counts()
# Out:
# Coords
# (14.76616, -90.99132)    29
# (14.4647, -90.44078)     22
# (14.76617, -90.99133)    22
# (14.76619, -90.99134)    21
# (14.46466, -90.44077)    20
#                          ..
# (14.76101, -90.99162)     1
# (14.75916, -90.99158)     1
# (14.46618, -90.44053)     1
# (14.46215, -90.44013)     1
# (14.52499, -90.18986)     1
# Name: count, Length: 266, dtype: int64

# %%
estaciones['Coords'] = estaciones['Coords'].replace('Error', "('NA', 'NA')")

# %%
len(df3)
# Out:
# 2760

# %%
estaciones
# Out:
#                            Nombre_comercial                         Direccion  \
# 0           ESTACION DE SERVICIO AEROPUERTO  1 AVENIDA 1-10 ZONA 10 GUATEMALA
# 1      ESTACION DE SERVICIO ALAMEDA PALMIRA   1 AVENIDA 1-10 ZONA 7 GUATEMALA
# 2      ESTACION DE SERVICIO ALCARAVAN YOPAL   1 AVENIDA 1-10 ZONA 9 GUATEMALA
# 3    ESTACION DE SERVICIO ALTO DE GUALANDAY  1 AVENIDA 1-11 ZONA 16 GUATEMALA
# 4       ESTACION DE SERVICIO AMERICAS PASTO  1 AVENIDA 1-11 ZONA 19 GUATEMALA
# ..                                      ...                               ...
# 915                SERVICENTRO PANAMERICANA  9 AVENIDA 4-21 ZONA 14 GUATEMALA
# 916                       SERVICENTRO PASTO  9 AVENIDA 4-21 ZONA 19 GUATEMALA
# 917          SERVICENTRO PLAZA BOLVAR S.A.S   9 AVENIDA 4-21 ZONA 7 GUATEMALA
# 918         SERVICENTRO PLAZA BOLIVAR S.A.S   9 AVENIDA 4-9 ZONA 12 GUATEMALA
# 919          SERVICENTRO PRIMAX EL PORVENIR    9 AVENIDA 4-9 ZONA 8 GUATEMALA
#
#                                     Full_Address                 Coords
# 0    1 AVENIDA 1-10 ZONA 10 GUATEMALA, GUATEMALA  (14.46466, -90.44077)
# 1     1 AVENIDA 1-10 ZONA 7 GUATEMALA, GUATEMALA  (14.46466, -90.44077)
# 2     1 AVENIDA 1-10 ZONA 9 GUATEMALA, GUATEMALA  (14.46466, -90.44077)
# 3    1 AVENIDA 1-11 ZONA 16 GUATEMALA, GUATEMALA  (14.64945, -90.89139)
# 4    1 AVENIDA 1-11 ZONA 19 GUATEMALA, GUATEMALA  (14.46466, -90.44077)
# ..                                           ...                    ...
# 915  9 AVENIDA 4-21 ZONA 14 GUATEMALA, GUATEMALA   (15.16291, -90.8537)
# 916  9 AVENIDA 4-21 ZONA 19 GUATEMALA, GUATEMALA  (14.76617, -90.99133)
# 917   9 AVENIDA 4-21 ZONA 7 GUATEMALA, GUATEMALA  (14.76617, -90.99133)
# 918   9 AVENIDA 4-9 ZONA 12 GUATEMALA, GUATEMALA   (14.7029, -91.86182)
# 919    9 AVENIDA 4-9 ZONA 8 GUATEMALA, GUATEMALA   (14.7029, -91.86182)
#
# [907 rows x 4 columns]

# %%
df_final = pd.merge(df3,estaciones[['Full_Address','Coords']],how = 'inner' , on = 'Full_Address')

# %%
df_final.head(3)
# Out:
#    Periodo  Mes  Codigo_departamento Departamento  Codigo_municipio  \
# 0     2023   12                    1    GUATEMALA              1010
# 1     2023   12                    1    GUATEMALA              1010
# 2     2023   12                    1    GUATEMALA              1010
#
#    Municipio                 Nombre_comercial Bandera  \
# 0  GUATEMALA  ESTACION DE SERVICIO AEROPUERTO  TEXACO
# 1  GUATEMALA  ESTACION DE SERVICIO AEROPUERTO  TEXACO
# 2  GUATEMALA  ESTACION DE SERVICIO AEROPUERTO  TEXACO
#
#                           Direccion Producto  Precio Estado  \
# 0  1 AVENIDA 1-10 ZONA 10 GUATEMALA   DIESEL   35.15      A
# 1  1 AVENIDA 1-10 ZONA 10 GUATEMALA  REGULAR   36.50      A
# 2  1 AVENIDA 1-10 ZONA 10 GUATEMALA    SUPER   37.20      A
#
#                                   Full_Address                 Coords
# 0  1 AVENIDA 1-10 ZONA 10 GUATEMALA, GUATEMALA  (14.46466, -90.44077)
# 1  1 AVENIDA 1-10 ZONA 10 GUATEMALA, GUATEMALA  (14.46466, -90.44077)
# 2  1 AVENIDA 1-10 ZONA 10 GUATEMALA, GUATEMALA  (14.46466, -90.44077)

# %%
df_final.to_csv('DATASET_FINAL.CSV',index = False)

# %%
df_final.to_excel('DATASET_FINAL.xlsx', index=False, engine='openpyxl')
